# %%
import pandas as pd

df = pd.read_csv('search_results_2.csv')

# %%
df.head()
# Out:
#                   author  record_count  record_enumerated  \
# 0   ['C. F. Williamson']             1                  0
# 1  ['David Halliburton']             4                  0
# 2  ['David Halliburton']             4                  1
# 3  ['David Halliburton']             4                  2
# 4  ['David Halliburton']             4                  3
#
#                                      viaf_title_list   birthdate title_list
# 0                                                 []        1860        NaN
# 1  ['America : the diary of a visit winter 1884-1...        1950        NaN
# 2  ['Budget speech, 1961:', 'eBay website, IMS Vi...  1921-08-22        NaN
# 3                          ['Faces of Hope, c1997:']           0        NaN
# 4                                                 []           0        NaN

# %%
len(df)
# Out:
# 72721

# %%
#reassociate S2 metadata with each author name

#read in the full dataset
# Load the metadata TSV file into a DataFrame
file_path = '\\Users\\bscag\\novelty\\becca\\LitMetadataWithS2 (3).tsv'

import pandas as pd
meta = pd.read_csv(file_path, sep='\t')
import requests

# %%
#normalize the text
import re

def normalize_text(text):
    """
    Normalize the text by converting to lowercase, preserving commas and spaces,
    and removing unnecessary special characters.
    """
    try:
        text = str(text)
        text = text.lower()  # Convert to lowercase
        text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
        text = re.sub(r'[^\w\s,]', '', text)  # Remove all characters except alphanumeric, spaces, and commas
        return text.strip()  # Trim leading and trailing spaces
    except:
        return ''
# df['normalized_author'] = df['author'].apply(normalize_text)
df['normalized_author'] = ""

for idx, row in df.iterrows():
    text = row['author']
    normalized_text = normalize_text(text)
    df.at[idx,'normalized_author'] = normalized_text

# %%
meta['author'] = meta['authors']

# %%
from ast import literal_eval 

rows = []
for index, row in meta.iterrows():
    author = row['author']
    author = normalize_text(author)
    # author = literal_eval(author)
    if ',' in author:
        author_list = author.split(',')
        # author_list = literal_eval(author_list)
        for author in author_list:
            new_row = {
             'author': author,
            'journal': row['journal'],
            'year': row['year'],
            'title': row['title'],
            'S2titles': row['S2titles'],
            'S2Years': row['S2years'],
            
        }
        rows.append(new_row)
    else:
        row_orig = {     
            'author': row['author'],
            'journal': row['journal'],
            'year': row['year'],
            'title': row['title'],
            'S2titles': row['S2titles'],
            'S2Years': row['S2years'],
            
        }
        rows.append(row_orig)

# %%
#this was the list of unique authors we used in our VIAF search
unique_author_names = []

for author_name in df['author']:
    if author_name not in unique_author_names:
        unique_author_names.append(author_name)

# %%
S2_data_dict = {}

for author_name in unique_author_names:
    for row in rows:
        if author_name == row['author']:
            S2_data_dict[author_name] = S2_row

# %%
for key, value in S2_data_dict.items():
    print(key, value)
    break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 2
#       1 for key, value in S2_data_dict.items():
# ----> 2     print(key[1], value[1])
#       3     break
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 1

# %%
# df['S2_data'] = df['author'].map(S2_data_dict[author]['title_list'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df['S2_data'] = df['author'].map(S2_data_dict[author]['title_list'])
#
# KeyError: 'l h c thomas'

# %%
# S2_data_dict['title_list']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 S2_data_dict['title_list']
#
# KeyError: 'title_list'

# %%
df
# Out:
#                          author  record_count  record_enumerated  \
# 0          ['C. F. Williamson']             1                  0
# 1         ['David Halliburton']             4                  0
# 2         ['David Halliburton']             4                  1
# 3         ['David Halliburton']             4                  2
# 4         ['David Halliburton']             4                  3
# ...                         ...           ...                ...
# 72716      ['John T. Matthews']             3                  0
# 72717      ['John T. Matthews']             3                  1
# 72718      ['John T. Matthews']             3                  2
# 72719  ['Melissa J. Homestead']             1                  0
# 72720    ['Barrie Ruth Straus']             1                  0
#
#                                          viaf_title_list   birthdate  \
# 0                                                     []        1860
# 1      ['America : the diary of a visit winter 1884-1...        1950
# 2      ['Budget speech, 1961:', 'eBay website, IMS Vi...  1921-08-22
# 3                              ['Faces of Hope, c1997:']           0
# 4                                                     []           0
# ...                                                  ...         ...
# 72716  ['Anxious souls will ask... : the Christ-cente...  1950-03-21
# 72717  ['Anxious souls will ask--, 2005:', 'Bonhoeffe...  1949-11-19
# 72718                                                 []           0
# 72719  ['American women authors and literary property...  1963-04-13
# 72720                    ['The Catholic Church, c1986:']           0
#
#                                               title_list    normalized_author  \
# 0                                                    NaN       c f williamson
# 1                                                    NaN    david halliburton
# 2                                                    NaN    david halliburton
# 3                                                    NaN    david halliburton
# 4                                                    NaN    david halliburton
# ...                                                  ...                  ...
# 72716  The Marriage of Speaking and Hearing in Absalo...      john t matthews
# 72717  The Marriage of Speaking and Hearing in Absalo...      john t matthews
# 72718  The Marriage of Speaking and Hearing in Absalo...      john t matthews
# 72719                                                NaN  melissa j homestead
# 72720  The Subversive Discourse of the Wife of Bath: ...   barrie ruth straus
#
#                                                  S2_data  \
# 0                             author  record_count  r...
# 1                             author  record_count  r...
# 2                             author  record_count  r...
# 3                             author  record_count  r...
# 4                             author  record_count  r...
# ...                                                  ...
# 72716                         author  record_count  r...
# 72717                         author  record_count  r...
# 72718                         author  record_count  r...
# 72719                         author  record_count  r...
# 72720                         author  record_count  r...
#
#                                             S2_titlelist
# 0      72720    The Subversive Discourse of the Wife ...
# 1      72720    The Subversive Discourse of the Wife ...
# 2      72720    The Subversive Discourse of the Wife ...
# 3      72720    The Subversive Discourse of the Wife ...
# 4      72720    The Subversive Discourse of the Wife ...
# ...                                                  ...
# 72716  72720    The Subversive Discourse of the Wife ...
# 72717  72720    The Subversive Discourse of the Wife ...
# 72718  72720    The Subversive Discourse of the Wife ...
# 72719  72720    The Subversive Discourse of the Wife ...
# 72720  72720    The Subversive Discourse of the Wife ...
#
# [72721 rows x 9 columns]

# %%
for author in unique_author_names[:2]:
    title_list = S2_data_dict[author]['title_list']
    print(author, title_list)
# Out:
# ['C. F. Williamson'] 72720    The Subversive Discourse of the Wife of Bath: ...
# Name: title_list, dtype: object
# ['David Halliburton'] 72720    The Subversive Discourse of the Wife of Bath: ...
# Name: title_list, dtype: object

# %%
def is_author_in_dict(author, dict):
    if author in dict.keys():
        return True



df['S2_titlelist'] = ""
for idx, row in df.iterrows():
    author = row['author']
    if is_author_in_dict(author, S2_data_dict):
        df.at[idx, 'S2_titlelist'] = S2_data_dict[author]['title_list']
    else:
        continue

# %%
df
# Out:
#                          author  record_count  record_enumerated  \
# 0          ['C. F. Williamson']             1                  0
# 1         ['David Halliburton']             4                  0
# 2         ['David Halliburton']             4                  1
# 3         ['David Halliburton']             4                  2
# 4         ['David Halliburton']             4                  3
# ...                         ...           ...                ...
# 72716      ['John T. Matthews']             3                  0
# 72717      ['John T. Matthews']             3                  1
# 72718      ['John T. Matthews']             3                  2
# 72719  ['Melissa J. Homestead']             1                  0
# 72720    ['Barrie Ruth Straus']             1                  0
#
#                                          viaf_title_list   birthdate  \
# 0                                                     []        1860
# 1      ['America : the diary of a visit winter 1884-1...        1950
# 2      ['Budget speech, 1961:', 'eBay website, IMS Vi...  1921-08-22
# 3                              ['Faces of Hope, c1997:']           0
# 4                                                     []           0
# ...                                                  ...         ...
# 72716  ['Anxious souls will ask... : the Christ-cente...  1950-03-21
# 72717  ['Anxious souls will ask--, 2005:', 'Bonhoeffe...  1949-11-19
# 72718                                                 []           0
# 72719  ['American women authors and literary property...  1963-04-13
# 72720                    ['The Catholic Church, c1986:']           0
#
#                                               title_list    normalized_author  \
# 0                                                    NaN       c f williamson
# 1                                                    NaN    david halliburton
# 2                                                    NaN    david halliburton
# 3                                                    NaN    david halliburton
# 4                                                    NaN    david halliburton
# ...                                                  ...                  ...
# 72716  The Marriage of Speaking and Hearing in Absalo...      john t matthews
# 72717  The Marriage of Speaking and Hearing in Absalo...      john t matthews
# 72718  The Marriage of Speaking and Hearing in Absalo...      john t matthews
# 72719                                                NaN  melissa j homestead
# 72720  The Subversive Discourse of the Wife of Bath: ...   barrie ruth straus
#
#                                                  S2_data  \
# 0                             author  record_count  r...
# 1                             author  record_count  r...
# 2                             author  record_count  r...
# 3                             author  record_count  r...
# 4                             author  record_count  r...
# ...                                                  ...
# 72716                         author  record_count  r...
# 72717                         author  record_count  r...
# 72718                         author  record_count  r...
# 72719                         author  record_count  r...
# 72720                         author  record_count  r...
#
#                                             S2_titlelist
# 0      72720    The Subversive Discourse of the Wife ...
# 1      72720    The Subversive Discourse of the Wife ...
# 2      72720    The Subversive Discourse of the Wife ...
# 3      72720    The Subversive Discourse of the Wife ...
# 4      72720    The Subversive Discourse of the Wife ...
# ...                                                  ...
# 72716  72720    The Subversive Discourse of the Wife ...
# 72717  72720    The Subversive Discourse of the Wife ...
# 72718  72720    The Subversive Discourse of the Wife ...
# 72719  72720    The Subversive Discourse of the Wife ...
# 72720  72720    The Subversive Discourse of the Wife ...
#
# [72721 rows x 9 columns]
